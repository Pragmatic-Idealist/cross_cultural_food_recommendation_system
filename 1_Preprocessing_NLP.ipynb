# %%
import os

#core dependencies
import pandas as pd
import numpy as np
import json
import re


#sklearn machine learning libraries
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from IPython.display import display, HTML
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud

#visualizations
import matplotlib
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#LDA Libraries
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

#NLP Libraries
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
import spacy

#Visualizations
import pyLDAvis
import pyLDAvis.sklearn

# %% [markdown]
# # 1. Load Data

# %%
#Function for loading and reading files
def load_data(lists_folder='data/lists/'):
    
    # Load the basic information on the recipes
    df = None
    for file in os.listdir(lists_folder):
        if 'DS_' in file:
            continue
        file_path = os.path.join(lists_folder, file)
        with open(file_path) as sd:
            data = json.load(sd)['matches']
        cdf = pd.DataFrame(data)
        cdf['cuisine'] = file.split('.')[0].split('_')[-2]
        df = (cdf if df is None else pd.concat([df, cdf]))
    df = df[['flavors', 'id', 'ingredients', 'recipeName', 'cuisine']]

    return df

# %%
#Simple function that lemmatizes a description
scy = spacy.load("en_core_web_sm")
def desc_prepro(desc):
    doc = scy(desc)
    words = [token.lemma_ for token in doc]
    return ' '.join(words)

# %%
df = load_data()

# %% [markdown]
# #  2. Data Transformation

# %%
#drop dupliate recipes

df.drop_duplicates('id', inplace = True)
df.head()
# Out:
#                                              flavors  \
# 0  {'piquant': 0.6666666666666666, 'meaty': 0.166...
# 1                                               None
# 2  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 3  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 4  {'piquant': 0.16666666666666666, 'meaty': 0.16...
#
#                                                   id  \
# 0                        Easy-Seafood-Paella-2077829
# 1  Skillet-Grilled-Seafood-and-Chorizo-Paella_-21...
# 2                 Spanish-style-garlic-shrimp-298317
# 3                              Classic-Paella-898818
# 4           One-Pot-Spanish-Chicken-and-Rice-2237989
#
#                                          ingredients  \
# 0  [lobster tails, water, olive oil, yellow onion...
# 1  [olive oil, sweet onion, garlic, spanish chori...
# 2  [I Can't Believe It's Not Butter!® Spread, unc...
# 3  [extra-virgin olive oil, skinless chicken brea...
# 4  [olive oil, chicken thighs, salt, pepper, onio...
#
#                                     recipeName  cuisine
# 0                          Easy Seafood Paella  spanish
# 1  Skillet Grilled Seafood and Chorizo Paella.  spanish
# 2                  Spanish-style Garlic Shrimp  spanish
# 3                               Classic Paella  spanish
# 4             One Pot Spanish Chicken and Rice  spanish

# %%
#need to drop nulls for pca on flavors later
df['flavors'].isnull().value_counts()
# Out:
# False    11533
# True      5053
# Name: flavors, dtype: int64

# %%
#dropping recipes without flavor information
df = df.dropna(subset=['flavors'], axis = 0).reset_index( drop = True)
df['flavors'].isnull().value_counts()
# Out:
# False    11533
# Name: flavors, dtype: int64

# %%
#need to seperate flavors into seperate features
df['flavors'][0]
# Out:
# {'piquant': 0.6666666666666666,
#  'meaty': 0.16666666666666666,
#  'bitter': 0.3333333333333333,
#  'sweet': 0.16666666666666666,
#  'sour': 0.16666666666666666,
#  'salty': 0.16666666666666666}

# %%
#creating seperate columns for flavors
df['piquant'] = df['flavors'].apply(lambda x: x['piquant'])
df['meaty'] = df['flavors'].apply(lambda x: x['meaty'])
df['bitter'] = df['flavors'].apply(lambda x: x['bitter'])
df['sweet'] = df['flavors'].apply(lambda x: x['sweet'])
df['sour'] = df['flavors'].apply(lambda x: x['sour'])
df['salty'] = df['flavors'].apply(lambda x: x['salty'])

# %% [markdown]
# #  3. NLP and Machine Learning Prep

# %%
#Funtion that cleans strings for mlp
def nlp_ml_prep(string):
    #remove digits
    new_string = re.sub(r'\b\d+\b', '', string)
    #remove punctuation
    new_string = re.sub(r'[^\w\s]','',new_string)
    #set all to lower case
    new_string = new_string.lower()
    
    #need to standardize ingredients, some words like lowfat, reduced fat, black in black pepper etc need to be removed
    stopwords =['gluten free', 'sugar free', 'sugarfree','low fat', 'reduced fat', 'fat free', 'fatfree', 'nonfat',
         'reduced sodium', 'low sodium','salt free','sodium free', 'sweetened','unsweetened','large','extra large','oz','free range',
         'black','yellow','skinless','fresh','chopped','diced','sliced', 'uncooked', 'peeled', 'uncook','peel', 'and', 'or', 'devein', 'deveined',
          'medium','extravirgin', 'extra', 'virgin', 'extra virgin', 'brown', 'white','all-purpose','allpurpose', 'all purpose','clove','cold','hot','red']
    for word in stopwords:
        new_string = new_string.replace(word,'')
    
    #trim leading and trailing white spaces
    new_string = new_string.strip()
    
    #join whitespace into underscore, for two word ingredients such as olive oil => olive_oil
    new_string = re.sub(' ','_',new_string)
    
    return new_string

# %%
#applying cleaning function to ingredients column
df.ingredients = df.ingredients.apply(lambda x: list(map(lambda y: nlp_ml_prep(y), x)))

# %%
df.head()
# Out:
#                                              flavors  \
# 0  {'piquant': 0.6666666666666666, 'meaty': 0.166...
# 1  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 2  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 4  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
#
#                                          id  \
# 0               Easy-Seafood-Paella-2077829
# 1        Spanish-style-garlic-shrimp-298317
# 2                     Classic-Paella-898818
# 3  One-Pot-Spanish-Chicken-and-Rice-2237989
# 4               Portuguese-fish-stew-306395
#
#                                          ingredients  \
# 0  [lobster_tails, water, olive_oil, onion, spani...
# 1  [i_cant_believe_its_not_butter_spread, shrimp,...
# 2  [olive_oil, chicken_breasts, chicken_stock, sa...
# 3  [olive_oil, chicken_thighs, salt, pepper, onio...
# 4  [plum_tomatoes, savoy_cabbage, olive_oil, chiz...
#
#                          recipeName  cuisine   piquant     meaty    bitter  \
# 0               Easy Seafood Paella  spanish  0.666667  0.166667  0.333333
# 1       Spanish-style Garlic Shrimp  spanish  0.833333  0.833333  0.833333
# 2                    Classic Paella  spanish  0.166667  0.166667  0.333333
# 3  One Pot Spanish Chicken and Rice  spanish  0.166667  0.166667  0.166667
# 4              Portuguese Fish Stew  spanish  0.500000  0.166667  0.166667
#
#       sweet      sour     salty
# 0  0.166667  0.166667  0.166667
# 1  0.166667  0.666667  0.833333
# 2  0.166667  0.666667  0.166667
# 3  0.166667  0.833333  0.166667
# 4  0.166667  0.500000  0.333333

# %%
X = df.iloc[0:,5:11].values #extracting flavors

# %%
from sklearn.metrics import pairwise_distances

# %%
#Function to find pairwise distances of one recipe and return the most similar recipes
#Takes in indexes of recipe of interest

def get_similiar_flavor_recipes(recipe,number):
    X = df.iloc[0:,5:11].values
    dist_recipe = pairwise_distances(X, X[recipe].reshape(1,-1))
    matches = np.argsort(dist_recipe.transpose()[0], axis = -1)
    return df.iloc[matches[:number]].drop(recipe,axis = 0)

# %%
get_similiar_flavor_recipes(2,-1)
# Out:
#                                                  flavors  \
# 6620   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3747   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3416   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3999   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 6407   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3966   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 2018   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 266    {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 10107  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3516   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 2530   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 866    {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 9434   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 10543  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 160    {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 2507   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 8689   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 9829   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 168    {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 480    {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3745   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 2444   {'piquant': 0.3333333333333333, 'meaty': 0.166...
# 2499   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 11335  {'piquant': 0.3333333333333333, 'meaty': 0.166...
# 6838   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 4162   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 8057   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3393   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 150    {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 1969   {'piquant': 0.16666666666666666, 'meaty': 0.16...
# ...                                                  ...
# 7263   {'piquant': 0.6666666666666666, 'meaty': 1.0, ...
# 3978   {'piquant': 0.6666666666666666, 'meaty': 1.0, ...
# 2756   {'piquant': 0.6666666666666666, 'meaty': 1.0, ...
# 8200   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 10357  {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 3382   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 138    {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 3712   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 11218  {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 7464   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 3025   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 7298   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 10264  {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 6912   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 7551   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 2098   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 10069  {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 3808   {'piquant': 0.8333333333333334, 'meaty': 1.0, ...
# 1740   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 2834   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 6902   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 7034   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 7449   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 8234   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 3488   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 7451   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 7130   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 10084  {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 8052   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
# 9269   {'piquant': 1.0, 'meaty': 1.0, 'bitter': 1.0, ...
#
#                                                       id  \
# 6620                               Stuffed-shells-308656
# 3747                         Easy-Pumpkin-Masala-1532616
# 3416                       Weeknight-Tikka-Masala-622193
# 3999   Grilled-steak-and-tomato-salad-with-rum-vinaig...
# 6407                         Pasta-AllArrabbiata-1035521
# 3966          Mushroom_-Spinach-_-Chickpea-Curry-1230721
# 2018                              Irish-Lamb-Stew-895797
# 266                                Guiso-de-pulpo-324966
# 10107           Seafood-Pasta-_portuguese-Style_-1477561
# 3516            Slow-Cooker-Chicken-Tikka-Masala-2262252
# 2530   Eggplant-Involtini-with-Moroccan-Marinara-Sauc...
# 866    Grilled-Vegetable-Ratatouille-With-Fried-Caper...
# 9434   Vegan-Bigos-_Polish-Sauerkraut-Stew_-_-Great-V...
# 10543                 Greek-Chicken-and-Potatoes-1023353
# 160                            Vegetarian-Paella-1463721
# 2507   Moroccan-tajine-with-sweet-potato_-chickpeas-a...
# 8689      Stir_fried-Garlic-Chives-With-Chile-Epicurious
# 9829       Easy-Cabbage-Rolls-With-Sauerkraut-Recipezaar
# 168              One-Pan-Vegetable-Quinoa-Paella-2037386
# 480         Paella-With-Rabbit-And-Artichokes-Epicurious
# 3745   Coconut-Cauliflower-Chickpea-Curry-_Vegan_-162...
# 2444   Moroccan-Red-Lentil-Stew-with-Parsnip-Fries-11...
# 2499           Beef-Tagine-with-Butternut-Squash-1075989
# 11335           Thai-Red-Curry-Chicken-Meatballs-2182429
# 6838           Linguine-puttanesca-with-chickpeas-310162
# 4162                  Grilled-Vegetable-Pasta-My-Recipes
# 8057   Moroccan-Cottage-Pie-with-Sweet-Potato-Mash-19...
# 3393                   Quick-Fall-Vegetable-Curry-981383
# 150          Fennel_-Tomato-And-Red-Pepper-Paella-939496
# 1969   Bangers-And-Mash-With-Creamed-Onion-Sauce-Reci...
# ...                                                  ...
# 7263                   Easy-Mexican-Chicken-Bake-1164528
# 3978                     Chicken-Avocado-Burgers-1031197
# 2756   Grilled-Moroccan-Style-Pork-Tenderloin-With-Wa...
# 8200                  Baked-Honey-Garlic-Chicken-1083547
# 10357  Greek-Stuffed-Peppers-With-Spinach-_-Artichoke...
# 3382                         Chicken-Tikka-Masala-986613
# 138               Spanish-Chicken-Chorizo-Paella-1216629
# 3712               Indian-Cauliflower-Fried-Rice-2209221
# 11218                      Pad-Thai-Spring-Rolls-1498222
# 7464                      Salsa-and-Pork-Fajitas-2210596
# 3025   Crockpot-Cuban-Pork-with-Beans-and-Fresh-Tomat...
# 7298                           Sheet-Pan-Fajitas-1079050
# 10264                      Greek-Chicken-Burgers-1180611
# 6912          One-Pot-Southwest-Chicken-and-Rice-2026503
# 7551                    Arugula-and-Pepita-Pesto-1933780
# 2098               Sweet-_-Spicy-Moroccan-Shrimp-1667729
# 10069                        Portuguese-Feijoada-1093798
# 3808     Slow-Cooker-Spicy-Vegetable-Lentil-Stew-1204373
# 1740            Irish-Shepherds-Pie-With-Guinness-901958
# 2834                    Authentic-Cuban-Picadillo-755182
# 6902       Lazy-Girls-Chicken-Enchilada-Casserole-475009
# 7034              Southwestern-Chicken-Casserole-1068852
# 7449                         Shredded-Beef-Tacos-2218191
# 8234                          Firecracker-Chicken-577500
# 3488                  Easy-Mixed-Vegetable-Curry-1317930
# 7451                      Roast-Beef-Quesadillas-2211050
# 7130                       Crockpot-Chicken-Tacos-676675
# 10084     Portuguese-Shrimp-Mozambique-with-Rice-2129989
# 8052   Homemade-Beef-Burger-with-Stilton-Rarebit_-Bur...
# 9269     Ultimate-Swedish-Meatballs-_Sorry-Ikea_-1027085
#
#                                              ingredients  \
# 6620   [lemon, olive_oil, crushed__pepper_flakes, fin...
# 3747   [pumpkin, small_potatoes, ginger, olive_oil, g...
# 3416   [oil, onions, garlic, chicken_pieces, smoked_p...
# 3999   [flank_steak, olive_oil, salt, ly_ground_peppe...
# 6407   [olive_oil, garlic, pepper_flakes, plum_tomato...
# 3966   [rapeseed_oil, onions, ginger, curry_powder, m...
# 2018   [leg_of_lamb, potatoes, leeks, carrots, celery...
# 266    [onions, garlic, bay_leaves, sweet_pepper, ita...
# 10107  [shrimp, clams, onions, garlic, salt, cier, to...
# 3516   [ginger, garlic, tomato_passata, coconut_milk,...
# 2530   [eggplant, ricotta_cheese, garlic, green_onion...
# 866    [bell_pepper, peppers, zucchini, eggplant, can...
# 9434   [olive_oil, seitan, onions, green_cabbage, cre...
# 10543  [lemon_juice, garlic, flat_leaf_parsley, basil...
# 160    [olive_oil, onions, bell_pepper, green_beans, ...
# 2507   [onions, garlic_s, sweet_potatoes, bell_pepper...
# 8689    [peanut_oil, garlic_chives, pepper_flakes, salt]
# 9829   [ground_pk, rice, onions, pepper, garlic_powde...
# 168    [olive_oil, onion, garlic_s, crimini_mushrooms...
# 480    [lemon, artichokes, tomatoes, rabbit, salt, pe...
# 3745   [coconut_oil, onions, garlic_s, ginger, cumin_...
# 2444   [olive_oil, carrots, onion, garlic, ground_cum...
# 2499   [paprika, ground_cinnamon, salt, ground_ginger...
# 11335  [ground_chicken, panko_breadcrumbs, garlic, gi...
# 6838   [olive_oil, garlic, anchovies, pepper_flakes, ...
# 4162   [tomatoes, onions, zucchini, squash, garlic_s,...
# 8057   [sweet_potatoes, butter, salt, pepper, olive_o...
# 3393   [coconut_oil, sweet_potatoes, cauliflower, oni...
# 150    [stock, olive_oil, onions, pepper, green_peppe...
# 1969   [onions, rosemary, pepper, salt, potatoes, sau...
# ...                                                  ...
# 7263   [chicken_breasts, beans, tomatoes, poblano_pep...
# 3978   [ground_chicken, avocado, garlic, panko, jalap...
# 2756   [pk_tenderloin, ground_cier, ground_cumin, kos...
# 8200   [chicken_breasts, eggs, panko_breadcrumbs, sal...
# 10357  [perdue_fit__easy__ground_chicken_filet_of_bre...
# 3382   [boneless__chicken_breasts, onions, garlic, gi...
# 138    [chicken_breasts, sea_salt, ground__pepper, ol...
# 3712   [cauliflower, canola_oil, cumin_seed, garlic, ...
# 11218  [firm_tofu, rice_noodles, rice_paper, carrots,...
# 7464   [boneless_pk_shoulder_roast, chili_powder, gro...
# 3025   [chicken_stock, ange_juice, cilantro, ange, sa...
# 7298   [chicken_breasts, pepper, green_pepper, pepper...
# 10264  [ground_chicken, roasted__peppers, feta_cheese...
# 6912   [boneless_chicken_breast, rice, olive_oil, chi...
# 7551   [roasted_pepitas, garlic, arugula, lemon_juice...
# 2098   [flour, paprika, salt, garlic_powder, ground_c...
# 10069  [beans, ham_hock, sausages, pk_shoulder, carro...
# 3808   [olive_oil, onions, carrots, bell_pepper, cele...
# 1740   [olive_oil, lean_ground_beef, sea_salt, onions...
# 2834   [mild_olive_oil, green_pepper, onions, garlic,...
# 6902   [chicken_breasts, salt, pepper, enchilada_sauc...
# 7034   [minute_rice, chicken_broth, onions, cn, beans...
# 7449   [skirt_steak, onion, garlic, wcestershire_sauc...
# 8234   [boneless__chicken_breasts, kosher_salt, groun...
# 3488   [olive_oil, onions, garlic_s, ginger, serrano_...
# 7451   [au_jus, chunky_salsa, pepper, flour_ttillas, ...
# 7130   [taco_seasoning, boneless__chicken_breasts, sa...
# 10084  [shrimp, garlic, unsalted_butter, modelo_beer,...
# 8052   [minced_beef, onions, garlic_s, wcestershire_s...
# 9269   [ground_pk, butter, plain_flour, chicken_stock...
#
#                                               recipeName     cuisine  \
# 6620                                      Stuffed Shells     italian
# 3747                                 Easy Pumpkin Masala      indian
# 3416                              Weeknight Tikka Masala      indian
# 3999   Grilled Steak and Tomato Salad with Rum Vinaig...    american
# 6407                                Pasta All’Arrabbiata     italian
# 3966                  Mushroom, Spinach & Chickpea Curry      indian
# 2018                                     Irish Lamb Stew       irish
# 266                                       Guiso de Pulpo     spanish
# 10107                   Seafood Pasta (portuguese Style)  portuguese
# 3516                    Slow Cooker Chicken Tikka Masala      indian
# 2530     Eggplant Involtini with Moroccan Marinara Sauce    moroccan
# 866      Grilled Vegetable Ratatouille With Fried Capers      french
# 9434   Vegan Bigos (Polish Sauerkraut Stew) + Great V...      german
# 10543                         Greek Chicken and Potatoes       greek
# 160                                    Vegetarian Paella     spanish
# 2507   Moroccan Tajine with Sweet Potato, Chickpeas a...    moroccan
# 8689                 Stir-Fried Garlic Chives with Chile     chinese
# 9829                  Easy Cabbage Rolls with Sauerkraut      german
# 168                      One Pan Vegetable Quinoa Paella     spanish
# 480                    Paella with Rabbit and Artichokes     spanish
# 3745          Coconut Cauliflower Chickpea Curry {Vegan}      indian
# 2444         Moroccan Red Lentil Stew with Parsnip Fries    moroccan
# 2499                   Beef Tagine with Butternut Squash    moroccan
# 11335                   Thai Red Curry Chicken Meatballs        thai
# 6838                  Linguine Puttanesca with Chickpeas     italian
# 4162                             Grilled Vegetable Pasta    american
# 8057         Moroccan Cottage Pie with Sweet Potato Mash     english
# 3393                          Quick Fall Vegetable Curry      indian
# 150                 Fennel, Tomato And Red Pepper Paella     spanish
# 1969           Bangers and Mash with Creamed Onion Sauce       irish
# ...                                                  ...         ...
# 7263                           Easy Mexican Chicken Bake     mexican
# 3978                             Chicken Avocado Burgers    american
# 2756   Grilled Moroccan Style Pork Tenderloin With Wa...    moroccan
# 8200                          Baked Honey Garlic Chicken     chinese
# 10357     Greek Stuffed Peppers With Spinach & Artichoke       greek
# 3382                                Chicken Tikka Masala      indian
# 138                       Spanish Chicken-Chorizo Paella     spanish
# 3712                       Indian Cauliflower Fried Rice      indian
# 11218                              Pad Thai Spring Rolls        thai
# 7464                              Salsa and Pork Fajitas     mexican
# 3025   Crockpot Cuban Pork with Beans and Fresh Tomat...       cuban
# 7298                                   Sheet Pan Fajitas     mexican
# 10264                              Greek Chicken Burgers       greek
# 6912                  One Pot Southwest Chicken and Rice     mexican
# 7551                            Arugula and Pepita Pesto     english
# 2098                       Sweet & Spicy Moroccan Shrimp    moroccan
# 10069                                Portuguese Feijoada  portuguese
# 3808             Slow Cooker Spicy Vegetable Lentil Stew      indian
# 1740                  Irish Shepherd’s Pie With Guinness       irish
# 2834                           Authentic Cuban Picadillo       cuban
# 6902             Lazy Girl’s Chicken Enchilada Casserole     mexican
# 7034                      Southwestern Chicken Casserole     mexican
# 7449                                 Shredded Beef Tacos     mexican
# 8234                                 Firecracker Chicken     chinese
# 3488                          Easy Mixed Vegetable Curry      indian
# 7451                              Roast Beef Quesadillas     mexican
# 7130                              Crockpot Chicken Tacos     mexican
# 10084             Portuguese Shrimp Mozambique with Rice  portuguese
# 8052   Homemade Beef Burger with Stilton Rarebit, Bur...     english
# 9269             Ultimate Swedish Meatballs (Sorry Ikea)     swedish
#
#         piquant     meaty    bitter     sweet      sour     salty
# 6620   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 3747   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 3416   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 3999   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 6407   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 3966   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 2018   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 266    0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 10107  0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 3516   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 2530   0.166667  0.166667  0.333333  0.166667  0.666667  0.166667
# 866    0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 9434   0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 10543  0.166667  0.166667  0.500000  0.166667  0.666667  0.166667
# 160    0.166667  0.166667  0.333333  0.166667  0.666667  0.333333
# 2507   0.166667  0.166667  0.333333  0.333333  0.666667  0.166667
# 8689   0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 9829   0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 168    0.166667  0.166667  0.333333  0.166667  0.666667  0.333333
# 480    0.166667  0.166667  0.333333  0.166667  0.666667  0.333333
# 3745   0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 2444   0.333333  0.166667  0.333333  0.166667  0.666667  0.166667
# 2499   0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 11335  0.333333  0.166667  0.333333  0.166667  0.666667  0.166667
# 6838   0.166667  0.166667  0.500000  0.166667  0.666667  0.166667
# 4162   0.166667  0.166667  0.500000  0.166667  0.666667  0.166667
# 8057   0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 3393   0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 150    0.166667  0.166667  0.333333  0.166667  0.833333  0.166667
# 1969   0.166667  0.166667  0.333333  0.166667  0.666667  0.333333
# ...         ...       ...       ...       ...       ...       ...
# 7263   0.666667  1.000000  1.000000  1.000000  1.000000  1.000000
# 3978   0.666667  1.000000  1.000000  1.000000  1.000000  1.000000
# 2756   0.666667  1.000000  1.000000  1.000000  1.000000  1.000000
# 8200   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 10357  0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 3382   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 138    0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 3712   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 11218  0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 7464   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 3025   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 7298   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 10264  0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 6912   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 7551   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 2098   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 10069  0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 3808   0.833333  1.000000  1.000000  1.000000  1.000000  1.000000
# 1740   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2834   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 6902   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 7034   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 7449   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 8234   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 3488   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 7451   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 7130   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 10084  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 8052   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 9269   1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
#
# [11531 rows x 11 columns]

# %%
dist_recipe_3 = pairwise_distances(X, X[3].reshape(1,-1)) #respective distance for each reciepe in regards to X[3] can use cosine distances

# %%
dist_recipe_3[0] #need to flatten this array
# Out:
# array([0.84983659])

# %%
dist_recipe_3.transpose()[0]
# Out:
# array([0.84983659, 1.34370962, 0.23570226, ..., 0.95742711, 0.89752747,
#        1.01379376])

# %%
matches = np.argsort(dist_recipe_3.transpose()[0], axis = -1) #returns index of the dishes with the closest distance
#untransposed distances gives you a row of distances for each X

# %%
#make list of ingredients into a single string to be analyzed
ingredient_strings =[]

for ingredients in df['ingredients']:
    ingredients = ' '.join(ingredients)
    ingredient_strings.append(ingredients)

# %%
df['nlp_ingredients'] = ingredient_strings

# %%
#Lemmmatizing Process -- for futher standardization and NLP preperation. Takes about 7 Minutes
df['nlp_ingredients'] = df['nlp_ingredients'].map(desc_prepro)

# %%
#drop duplicate recipes

df.drop_duplicates(subset = 'id', inplace = True)

# %%
df.head()
# Out:
#                                              flavors  \
# 0  {'piquant': 0.6666666666666666, 'meaty': 0.166...
# 1  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 2  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 4  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
#
#                                          id  \
# 0               Easy-Seafood-Paella-2077829
# 1        Spanish-style-garlic-shrimp-298317
# 2                     Classic-Paella-898818
# 3  One-Pot-Spanish-Chicken-and-Rice-2237989
# 4               Portuguese-fish-stew-306395
#
#                                          ingredients  \
# 0  [lobster_tails, water, olive_oil, onion, spani...
# 1  [i_cant_believe_its_not_butter_spread, shrimp,...
# 2  [olive_oil, chicken_breasts, chicken_stock, sa...
# 3  [olive_oil, chicken_thighs, salt, pepper, onio...
# 4  [plum_tomatoes, savoy_cabbage, olive_oil, chiz...
#
#                          recipeName  cuisine   piquant     meaty    bitter  \
# 0               Easy Seafood Paella  spanish  0.666667  0.166667  0.333333
# 1       Spanish-style Garlic Shrimp  spanish  0.833333  0.833333  0.833333
# 2                    Classic Paella  spanish  0.166667  0.166667  0.333333
# 3  One Pot Spanish Chicken and Rice  spanish  0.166667  0.166667  0.166667
# 4              Portuguese Fish Stew  spanish  0.500000  0.166667  0.166667
#
#       sweet      sour     salty
# 0  0.166667  0.166667  0.166667
# 1  0.166667  0.666667  0.833333
# 2  0.166667  0.666667  0.166667
# 3  0.166667  0.833333  0.166667
# 4  0.166667  0.500000  0.333333

# %%
df.shape
# Out:
# (11533, 11)

# %%
df.iloc[4]
# Out:
# flavors        {'piquant': 0.5, 'meaty': 0.16666666666666666,...
# id                                   Portuguese-fish-stew-306395
# ingredients    [plum_tomatoes, savoy_cabbage, olive_oil, chiz...
# recipeName                                  Portuguese Fish Stew
# cuisine                                                  spanish
# piquant                                                      0.5
# meaty                                                   0.166667
# bitter                                                  0.166667
# sweet                                                   0.166667
# sour                                                         0.5
# salty                                                   0.333333
# Name: 4, dtype: object

# %%
#saving dataframe to csv
df.to_csv('nlp_ml_ready_recipes.csv')

# %% [markdown]
# #  4. Pairwise Distance on Flavors

# %%
df.head()
# Out:
#                                              flavors  \
# 0  {'piquant': 0.6666666666666666, 'meaty': 0.166...
# 1  {'piquant': 0.8333333333333334, 'meaty': 0.833...
# 2  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 3  {'piquant': 0.16666666666666666, 'meaty': 0.16...
# 4  {'piquant': 0.5, 'meaty': 0.16666666666666666,...
#
#                                          id  \
# 0               Easy-Seafood-Paella-2077829
# 1        Spanish-style-garlic-shrimp-298317
# 2                     Classic-Paella-898818
# 3  One-Pot-Spanish-Chicken-and-Rice-2237989
# 4               Portuguese-fish-stew-306395
#
#                                          ingredients  \
# 0  [lobster_tails, water, olive_oil, onion, spani...
# 1  [i_cant_believe_its_not_butter_spread, shrimp,...
# 2  [olive_oil, chicken_breasts, chicken_stock, sa...
# 3  [olive_oil, chicken_thighs, salt, pepper, onio...
# 4  [plum_tomatoes, savoy_cabbage, olive_oil, chiz...
#
#                          recipeName  cuisine   piquant     meaty    bitter  \
# 0               Easy Seafood Paella  spanish  0.666667  0.166667  0.333333
# 1       Spanish-style Garlic Shrimp  spanish  0.833333  0.833333  0.833333
# 2                    Classic Paella  spanish  0.166667  0.166667  0.333333
# 3  One Pot Spanish Chicken and Rice  spanish  0.166667  0.166667  0.166667
# 4              Portuguese Fish Stew  spanish  0.500000  0.166667  0.166667
#
#       sweet      sour     salty  \
# 0  0.166667  0.166667  0.166667
# 1  0.166667  0.666667  0.833333
# 2  0.166667  0.666667  0.166667
# 3  0.166667  0.833333  0.166667
# 4  0.166667  0.500000  0.333333
#
#                                      nlp_ingredients
# 0  lobster_tail water olive_oil onion spanish_ric...
# 1  i_cant_believe_its_not_butter_spread shrimp sa...
# 2  olive_oil chicken_breast chicken_stock saffron...
# 3  olive_oil chicken_thighs salt pepper onion gar...
# 4  plum_tomatoe savoy_cabbage olive_oil chizo_sau...

# %%
df.columns
# Out:
# Index(['flavors', 'id', 'ingredients', 'recipeName', 'cuisine', 'piquant',
#        'meaty', 'bitter', 'sweet', 'sour', 'salty', 'nlp_ingredients'],
#       dtype='object')

# %%
#create a new dataframe with just recipe name cuisine and flavors

df_flavors = df.drop(['flavors', 'id', 'ingredients', 'nlp_ingredients'], axis = 1)

# %%
df_flavors.head()
# Out:
#                          recipeName  cuisine   piquant     meaty    bitter  \
# 0               Easy Seafood Paella  spanish  0.666667  0.166667  0.333333
# 1       Spanish-style Garlic Shrimp  spanish  0.833333  0.833333  0.833333
# 2                    Classic Paella  spanish  0.166667  0.166667  0.333333
# 3  One Pot Spanish Chicken and Rice  spanish  0.166667  0.166667  0.166667
# 4              Portuguese Fish Stew  spanish  0.500000  0.166667  0.166667
#
#       sweet      sour     salty
# 0  0.166667  0.166667  0.166667
# 1  0.166667  0.666667  0.833333
# 2  0.166667  0.666667  0.166667
# 3  0.166667  0.833333  0.166667
# 4  0.166667  0.500000  0.333333

# %%
df_flavors.to_csv('name_cuisine_flavors.csv')

# %%
#Find most simliar recipe based on flavor profile
#Designate Data
X = df_flavors

# %% [markdown]
# # 5. Creating CSV for Topic Modeling

# %%
#create new data frame with just ingredients ready for nlpn name, and cuisine
df_ing = df.drop(['flavors', 'id', 'ingredients', 'piquant',
       'meaty', 'bitter', 'sweet', 'sour', 'salty'], axis = 1)

# %%
df_ing.head()
# Out:
#                          recipeName  cuisine  \
# 0               Easy Seafood Paella  spanish
# 1       Spanish-style Garlic Shrimp  spanish
# 2                    Classic Paella  spanish
# 3  One Pot Spanish Chicken and Rice  spanish
# 4              Portuguese Fish Stew  spanish
#
#                                      nlp_ingredients
# 0  lobster_tail water olive_oil onion spanish_ric...
# 1  i_cant_believe_its_not_butter_spread shrimp sa...
# 2  olive_oil chicken_breast chicken_stock saffron...
# 3  olive_oil chicken_thighs salt pepper onion gar...
# 4  plum_tomatoe savoy_cabbage olive_oil chizo_sau...

# %%
df_ing.to_csv('name_cuisine_nlptopicmodeling.csv')
